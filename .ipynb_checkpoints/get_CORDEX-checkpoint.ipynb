# %%
import cdsapi

dataset = "projections-cordex-domains-single-levels"
request = {
    "domain": "arctic",
    "experiment": "historical",
    "horizontal_resolution": "0_22_degree_x_0_22_degree",
    "temporal_resolution": "daily_mean",
    "variable": [
        "2m_air_temperature",
        "2m_surface_specific_humidity",
        "10m_u_component_of_the_wind",
        "10m_v_component_of_the_wind",
        "10m_wind_speed",
        "maximum_2m_temperature_in_the_last_24_hours",
        "minimum_2m_temperature_in_the_last_24_hours",
        "evaporation",
        "mean_sea_level_pressure",
        "mean_precipitation_flux",
        "surface_pressure",
        "surface_solar_radiation_downwards",
        "surface_thermal_radiation_downward",
        "total_cloud_cover"
    ],
    "gcm_model": "cccma_canesm2",
    "rcm_model": "cccma_canrcm4",
    "ensemble_member": "r1i1p1",
    "start_year": [
        "1950",
        "1951",
        "1956",
        "1961",
        "1966",
        "1971",
        "1976",
        "1981",
        "1986",
        "1991",
        "1996",
        "2001"
    ],
    "end_year": [
        "1950",
        "1955",
        "1960",
        "1965",
        "1970",
        "1975",
        "1980",
        "1985",
        "1990",
        "1995",
        "2000",
        "2005"
    ]
}

client = cdsapi.Client()
client.retrieve(dataset, request).download()
# Out:
# 2026-02-19 13:22:56,403 INFO Request ID is 4098a19b-dacb-4c7d-a1f7-38eff866508a
# 2026-02-19 13:22:56,610 INFO status has been updated to accepted
# 2026-02-19 13:23:09,553 INFO status has been updated to running
# 2026-02-19 14:37:43,710 INFO status has been updated to successful
# 7b12e6fb0bbc9126466f2728a8669ddf.zip:   0%|          | 0.00/43.5G [00:00<?, ?B/s]
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# '7b12e6fb0bbc9126466f2728a8669ddf.zip'

# %%
import cdsapi

dataset = "projections-cordex-domains-single-levels"
request = {
    "domain": "arctic",
    "experiment": "rcp_8_5",
    "horizontal_resolution": "0_22_degree_x_0_22_degree",
    "temporal_resolution": "daily_mean",
    "variable": [
        "2m_air_temperature",
        "2m_surface_specific_humidity",
        "10m_u_component_of_the_wind",
        "10m_v_component_of_the_wind",
        "10m_wind_speed",
        "maximum_2m_temperature_in_the_last_24_hours",
        "minimum_2m_temperature_in_the_last_24_hours",
        "evaporation",
        "mean_sea_level_pressure",
        "mean_precipitation_flux",
        "surface_pressure",
        "surface_solar_radiation_downwards",
        "surface_thermal_radiation_downward",
        "total_cloud_cover"
    ],
    "gcm_model": "cccma_canesm2",
    "rcm_model": "cccma_canrcm4",
    "ensemble_member": "r1i1p1",
    "start_year": [
        "2006",
        "2011",
        "2016",
        "2021",
        "2026",
        "2031",
        "2036",
        "2041",
        "2046",
        "2051",
        "2056",
        "2061",
        "2066",
        "2071",
        "2076",
        "2081",
        "2086",
        "2091",
        "2096"
    ],
    "end_year": [
        "2010",
        "2015",
        "2020",
        "2025",
        "2030",
        "2035",
        "2040",
        "2045",
        "2050",
        "2055",
        "2060",
        "2065",
        "2070",
        "2075",
        "2080",
        "2085",
        "2090",
        "2095",
        "2100"
    ]
}

client = cdsapi.Client()
client.retrieve(dataset, request).download()
# Out:
# 2026-02-19 15:43:32,859 INFO Request ID is 619553cd-c237-453f-89ae-6bff4889225d
# 2026-02-19 15:43:33,029 INFO status has been updated to accepted
# 2026-02-19 15:43:53,679 INFO status has been updated to running
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 73
#       4 request = {
#       5     "domain": "arctic",
#       6     "experiment": "rcp_8_5",
#    (...)
#      69     ]
#      70 }
#      72 client = cdsapi.Client()
# ---> 73 client.retrieve(dataset, request).download()
#
# File ~/.local/lib/python3.10/site-packages/cads_api_client/legacy_api_client.py:152, in LegacyApiClient.retrieve(self, name, request, target)
#     150 submitted: Remote | Results
#     151 if self.wait_until_complete:
# --> 152     submitted = self.client.submit_and_wait_on_results(
#     153         collection_id=name,
#     154         **request,
#     155     )
#     156 else:
#     157     submitted = self.client.submit(
#     158         collection_id=name,
#     159         **request,
#     160     )
#
# File ~/.local/lib/python3.10/site-packages/cads_api_client/api_client.py:456, in ApiClient.submit_and_wait_on_results(self, collection_id, **request)
#     440 def submit_and_wait_on_results(
#     441     self, collection_id: str, **request: Any
#     442 ) -> cads_api_client.Results:
#     443     """Submit a request and wait for the results to be ready.
#     444
#     445     Parameters
#    (...)
#     454     cads_api_client.Results
#     455     """
# --> 456     return self._retrieve_api.submit(collection_id, **request).make_results()
#
# File ~/.local/lib/python3.10/site-packages/cads_api_client/processing.py:525, in Remote.make_results(self, wait)
#     523 def make_results(self, wait: bool = True) -> Results:
#     524     if wait:
# --> 525         self._wait_on_results()
#     526     response = self._get_api_response("get")
#     527     try:
#
# File ~/.local/lib/python3.10/site-packages/cads_api_client/processing.py:521, in Remote._wait_on_results(self)
#     519     raise ProcessingFailedError(f"Unknown API state {status!r}")
#     520 self.debug(f"results not ready, waiting for {sleep} seconds")
# --> 521 time.sleep(sleep)
#
# KeyboardInterrupt:

# %%
import cdsapi

dataset = "projections-cordex-domains-single-levels"
request = {
    "domain": "arctic",
    "experiment": "rcp_8_5",
    "horizontal_resolution": "0_44_degree_x_0_44_degree",
    "temporal_resolution": "daily_mean",
    "gcm_model": "cccma_canesm2",
    "rcm_model": "cccma_canrcm4",
    "ensemble_member": "r1i1p1",
    "start_year": [
        "2006",
        "2011",
        "2016",
        "2021",
        "2026",
        "2031",
        "2036",
        "2041",
        "2046",
        "2051",
        "2056",
        "2061",
        "2066",
        "2071",
        "2076",
        "2081",
        "2086",
        "2091",
        "2096"
    ],
    "end_year": [
        "2010",
        "2015",
        "2020",
        "2025",
        "2030",
        "2035",
        "2040",
        "2045",
        "2050",
        "2055",
        "2060",
        "2065",
        "2070",
        "2075",
        "2080",
        "2085",
        "2090",
        "2095",
        "2100"
    ]
}

client = cdsapi.Client()
client.retrieve(dataset, request).download()
